# %% [markdown]
#  ## Data visualiztion
#      - MatplotLib
#      -Seaborn

# %% [markdown]
# ## Matplot Lib:
#      - this is one of the best python library for data visualization
#      - this is written by John D Hunter in the year 2003

# %% [markdown]
# ## matplot lib:
#     -Lineplot
#     -scatterplot
#     -barplot
#     -Histogram plot
#     -pichart

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[5,2,1,4]
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3,4]
y=[5,2,1,4]
z=[4,5,7,6]
plt.plot(x,y,z)
plt.show()

# %%
import numpy as np
x=np.array([23,12,34,23])
y=np.array([45,12,34,23])
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,color='m')
plt.show()

# %% [markdown]
# ### colors with symbols:
#     - megenta-m
#     - blue -b
#     - red  -r
#     - black -k
#     - cyan  -c
#     - green -g

# %%
plt.plot(x,y,color='b')
plt.show()

# %%
plt.plot(x,y,color='k')
plt.show()

# %%
plt.plot(x,y,color='g')
plt.show()

# %%
x1=np.array([1,2,3,4,5])
plt.plot(x1,x1**2,color='k')
x2=np.array([5,6,7,8,9])
plt.plot(x2,x2**2,color='m')
plt.show()

# %%
x1=np.array([1,2,3,4,5])
plt.plot(x1,pow(x1,2),color='k')
x2=np.array([5,6,7,8,9])
plt.plot(x2,pow(x2,3),color='m')
x3=np.array([10,11,12,13,14])
plt.plot(x3,pow(x3,3),color='g')
plt.show()

# %% [markdown]
# ### Symbols with colors:
#     -'color*'
#        - 'r*'
#        - 'c*'

# %%
plt.plot(x1,x2,'c*')

# %% [markdown]
# ### Symbols with colors and lines:
#     -'color*--'
#        - 'r*--'
#        - 'c--*'

# %%
plt.plot(x1,x2,'c*--')

# %%
plt.plot?

# %% [markdown]
# ``'b'``          blue
# ``'g'``          green
# ``'r'``          red
# ``'c'``          cyan
# ``'m'``          magenta
# ``'y'``          yellow
# ``'k'``          black
# ``'w'``          white

# %% [markdown]
# =============    ===============================
# character        description
# =============    ===============================
# ``'.'``          point marker
# ``','``          pixel marker
# ``'o'``          circle marker
# ``'v'``          triangle_down marker
# ``'^'``          triangle_up marker
# ``'<'``          triangle_left marker
# ``'>'``          triangle_right marker
# ``'1'``          tri_down marker
# ``'2'``          tri_up marker
# ``'3'``          tri_left marker
# ``'4'``          tri_right marker
# ``'s'``          square marker
# ``'p'``          pentagon marker
# ``'*'``          star marker
# ``'h'``          hexagon1 marker
# ``'H'``          hexagon2 marker
# ``'+'``          plus marker
# ``'x'``          x marker
# ``'D'``          diamond marker
# ``'d'``          thin_diamond marker
# ``'|'``          vline marker
# ``'_'``          hline marker
# =============    ===============================
#
# **Line Styles**
#
# =============    ===============================
# character        description
# =============    ===============================
# ``'-'``          solid line style
# ``'--'``         dashed line style
# ``'-.'``         dash-dot line style
# ``':'``          dotted line style
# =============    ===============================

# %%
plt.plot(x1,x2,'c',linestyle='solid',linewidth=5)

# %%
plt.plot(x1,x2,'c',linestyle=':',linewidth=5)

# %%
plt.plot(x1,x2,'c',linestyle='-.',linewidth=5)

# %% [markdown]
# ## Labels

# %%
plt.plot(x1,x2,'c^')
plt.title("this is demo label")
plt.xlabel('this is x label')
plt.ylabel('this is y label')
plt.show()

# %%
plt.legend?

# %% [markdown]
#  ===============   =============
#         Location String   Location Code
#         ===============   =============
#         'best'            0
#         'upper right'     1
#         'upper left'      2
#         'lower left'      3
#         'lower right'     4
#         'right'           5
#         'center left'     6
#         'center right'    7
#         'lower center'    8
#         'upper center'    9
#         'center'          10
#         ===============   =============

# %%
x=np.linspace(0,5,20)
x
# Out:
# array([0.        , 0.26315789, 0.52631579, 0.78947368, 1.05263158,
#        1.31578947, 1.57894737, 1.84210526, 2.10526316, 2.36842105,
#        2.63157895, 2.89473684, 3.15789474, 3.42105263, 3.68421053,
#        3.94736842, 4.21052632, 4.47368421, 4.73684211, 5.        ])

# %%
print(len(x))
# Out:
# 20

# %%
len(x)
# Out:
# 20

# %%
x=np.linspace(0,10,20)
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
plt.plot(x,x,'c*',label='line x vs x')
plt.plot(x,pow(x,2),'m^',label='line x vs pow(x)')
plt.legend(loc=0)
plt.show()

# %%
x=np.array([1,2,3,4,5])
plt.plot(x,x,'c*',label='line x vs x')
plt.plot(x,pow(x,2),'m^',label='line x vs pow(x)')
plt.legend(loc=1)
plt.show()

# %%
x=np.array([1,2,3,4,5])
plt.plot(x,x,'c*',label='line x vs x')
plt.plot(x,pow(x,2),'m^',label='line x vs pow(x)')
plt.legend(loc=2)
plt.show()

# %%
plt.plot(x,x,'c*',label='line x vs x')
plt.plot(x,pow(x,2),'m^',label='line x vs pow(x)')
plt.legend(loc=10)
plt.show()

# %% [markdown]
# ## subplot
#   plt.subplot(row,columns,position)

# %%
plt.subplots(2,2)
plt.show()

# %%
x=np.array([12,23,34,56,78])
y=np.array([13,24,56,78,73])
plt.subplot(3,3,1)
plt.plot(x,y,'r^')

# %%
x=np.array([12,23,34,56,78])
y=np.array([13,24,56,78,73])
plt.subplot(3,3,1)
plt.plot(x,y,'r^')
plt.subplot(3,3,2)
plt.plot(x,y,'c^')

# %%
x=np.array([12,23,34,56,78])
y=np.array([13,24,56,78,73])
plt.subplot(3,3,1)
plt.plot(x,y,'r^')
plt.subplot(3,3,2)
plt.plot(x,y,'c^')
plt.subplot(3,3,3)
plt.plot(x,y,'k^')

# %%
x=np.array([12,23,34,56,78])
y=np.array([13,24,56,78,73])
plt.subplot(3,3,1)
plt.plot(x,y,'r^')
plt.subplot(3,3,2)
plt.plot(x,y,'c^')
plt.subplot(3,3,3)
plt.plot(x,y,'k^')
plt.subplot(3,3,4)
plt.plot(x,y,'m^')

# %%
x=np.array([12,23,34,56,78])
y=np.array([13,24,56,78,73])
plt.subplot(3,3,1)
plt.plot(x,y,'r^')
plt.subplot(3,3,2)
plt.plot(x,y,'c^')
plt.subplot(3,3,3)
plt.plot(x,y,'k^')
plt.subplot(3,3,4)
plt.plot(x,y,'m^')
plt.subplot(3,3,5)
plt.plot(x,y,'g^')

# %%
x=np.array([12,23,34,56,78])
y=np.array([13,24,56,78,73])
plt.subplot(3,3,1)
plt.plot(x,y,'r^')
plt.subplot(3,3,2)
plt.plot(x,y,'c^')
plt.subplot(3,3,3)
plt.plot(x,y,'k^')
plt.subplot(3,3,4)
plt.plot(x,y,'m^')
plt.subplot(3,3,5)
plt.plot(x,y,'g^')
plt.subplot(3,3,6)
plt.plot(x,y,'b^')

# %% [markdown]
# ## Bar Plot
#     syntax- plt.bar(x,y.........)

# %%
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(x,y,width=5,color='c')
plt.show()

# %%
plt.bar(x,y,width=4,color='m')
# Out:
# <BarContainer object of 5 artists>

# %%
names=['bob','alice','kunshi','dora','tom','eve','jerry']
ages=[32,45,5,47,68,21,23]
plt.bar(names,ages)
plt.show()

# %%
plt.barh(names,ages)
plt.show()

# %%
plt.bar(names,ages)
plt.show()

# %% [markdown]
# ## Box plot
#  - it is also known as whisker plot
#  - parameters
#  - minimum(1,-5)
#  - first quadrent(25)
#  - second quadrent(25)

# %%
data=np.random.normal(100,20,200)
print(data)
# Out:
# [ 88.1474485  139.21274786 124.75309224  97.70907097  91.74171064
#   74.23572569 117.06876233  53.63741095  66.53162003  91.27798985
#  106.93973798 117.70498315  75.17961016 109.12004093  99.72585715
#  103.82704755 105.7019498  110.58879267  85.05043852 107.37901796
#  131.6117068   99.54568213  92.1366374  128.81148327 104.3960034
#   76.2447187  123.82012572 113.13573243 110.97070462  73.08533187
#   86.01121161 111.3653491   97.31150303 113.40777515  53.06919614
#  120.89407296 125.22466701 151.16217576  73.62032089  84.1945813
#  159.15450563 111.58400426  94.01801263 107.17564031  51.20224385
#  103.87920778  90.78379336 125.19498693  79.11575837  62.06273342
#   92.70538215  56.0565174   94.4722785  123.70890139 102.39390787
#   87.28095772  75.98524181  93.70137228  67.28909947 119.13848039
#   63.92171172  85.45865441 117.80447306  54.81921645 141.51612418
#  126.26342957 103.5705323   95.24371393  87.82826388 115.41739496
#  124.90265941  86.62320266  94.76414714 129.73656782  85.39659352
#  105.75354538 113.8874316   99.99937969 109.90684044 102.39323031
#   98.95025785 134.67891218  88.7570836   86.79599572  96.43876295
#   47.42210792  84.60507011 113.76436204 129.64048802 100.61411077
#  129.71054076  88.58439373  81.31127122 129.07130376 106.36497147
#   94.83265432 116.60092721 114.35092693 103.20124516  88.92786352
#   88.53386155 108.49575856 101.76860915 109.35676916  89.13173508
#  122.4302427   83.72812306 119.25817293  92.17747186  98.99713546
#   88.21622585  95.25796567 108.29828546 114.37428353  67.69619521
#  141.867517    64.78600127  80.9425411   84.40608176  85.82572769
#  126.72854408 120.64827538 136.36076932 142.91215363  74.37645068
#  109.4510765   84.23772013 118.44393217  90.31214812  75.26509401
#   89.28507098 114.86794096  51.40594604 113.36414338  86.26381177
#  107.41181164  89.27132179  96.55213912 131.87747627  78.27778263
#   88.91810907  72.85583366  65.42107491  74.91412002  82.59705045
#   64.4036162  125.61409741 114.59428006  70.09878688 118.47983108
#  131.06228792  56.44178907 101.64045447 103.50732084  55.53308779
#  115.65013729 120.64277152  78.85551795 100.59419064 128.3724571
#   94.39640561 120.56942199 118.08076787  73.0457266   90.66131669
#  122.76686904 108.89730183 129.50260436 115.96257434 135.50731773
#   73.84823552  95.03447761 102.43583633 109.40340702 127.31213998
#   92.13579718 117.87206884 101.77078811  68.13432155 117.07563817
#  126.9477572  114.67725175 100.12116667 103.5738701  131.99320081
#  109.14335679  68.03746448 124.44270374  89.96890556  93.93277789
#   70.25260864 113.2523424   92.47506954  96.94491704 125.84069177
#  112.24276416  72.25904306 127.23365437  87.09278918 121.9846506 ]

# %%
plt.boxplot(data)
plt.show()

# %%
data=np.random.randint(50,100,10)
print(data)
# Out:
# [81 67 66 65 75 85 85 57 83 51]

# %%
data1=np.random.randint(50,100,10)
print(data1)
data2=np.random.randint(40,90,10)
print(data2)
data3=np.random.randint(34,109,10)
print(data3)
dx=[data1,data2,data3]
dy=['a','b','c']
plt.boxplot(dx,dy)
plt.plot()
# Out:
# [91 60 88 85 54 54 68 84 59 84]
# [87 59 69 44 57 85 60 51 82 82]
# [102  97  91  53  85  54  64  52  36  60]
# []

# %%
data1=np.random.randint(50,100,10)
print(data1)
data2=np.random.randint(40,90,10)
print(data2)
data3=np.random.randint(34,109,10)
print(data3)
dx=[data1,data2,data3]
dy=['a','b','c']
plt.boxplot(dx,dy)
plt.plot()
plt.savefig('boxplot.png')
# Out:
# [76 68 68 80 72 81 70 69 53 50]
# [88 86 74 85 78 81 80 41 82 69]
# [ 58  35  93 105  82  92  85  47  98  59]

# %% [markdown]
# ### pichart
#     - dividing each piece of data(rows,cols)into separateand visualize

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0,0,0.5,0,0))
plt.show()

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0.2,0,0,0,0))
plt.show()

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0,0.3,0,0,0))
plt.show()

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0,0,0,0.4,0))
plt.show()

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0,0,0.5,0,0.5))
plt.show()

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0.2,0.6,0.5,0.2,0.7))
plt.show()

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0,0,0.5,0,0),autopct='%1.1f%%')
plt.show()

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0,0,0.5,0,0),autopct='%2.2f%%')
plt.show()
plt.savefig('piechart.png')

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0.2,0,0,0,0),autopct='%2.2f%%')
plt.show()
plt.savefig('piechart1.png')

# %%
branchescount=[500,600,800,250,350]
branches=['Ece','Civ','Cse','Mec','Eee']
colors=['r','c','b','m','g']
plt.pie(branchescount,labels=branches,startangle=90,shadow=True,explode=(0,0.3,0,0,0),autopct='%2.2f%%')
plt.show()
plt.savefig('piechart2.png')

# %% [markdown]
# # For project deployment
# - http://devcenter.heroku.com/articles/heroku-cli
# - http://heroku.com/

# %%
# list comprehension
roll_numbers=['172U1A0'+str(i) for i in range(500,600)]
print(roll_numbers)
# Out:
# ['172U1A0500', '172U1A0501', '172U1A0502', '172U1A0503', '172U1A0504', '172U1A0505', '172U1A0506', '172U1A0507', '172U1A0508', '172U1A0509', '172U1A0510', '172U1A0511', '172U1A0512', '172U1A0513', '172U1A0514', '172U1A0515', '172U1A0516', '172U1A0517', '172U1A0518', '172U1A0519', '172U1A0520', '172U1A0521', '172U1A0522', '172U1A0523', '172U1A0524', '172U1A0525', '172U1A0526', '172U1A0527', '172U1A0528', '172U1A0529', '172U1A0530', '172U1A0531', '172U1A0532', '172U1A0533', '172U1A0534', '172U1A0535', '172U1A0536', '172U1A0537', '172U1A0538', '172U1A0539', '172U1A0540', '172U1A0541', '172U1A0542', '172U1A0543', '172U1A0544', '172U1A0545', '172U1A0546', '172U1A0547', '172U1A0548', '172U1A0549', '172U1A0550', '172U1A0551', '172U1A0552', '172U1A0553', '172U1A0554', '172U1A0555', '172U1A0556', '172U1A0557', '172U1A0558', '172U1A0559', '172U1A0560', '172U1A0561', '172U1A0562', '172U1A0563', '172U1A0564', '172U1A0565', '172U1A0566', '172U1A0567', '172U1A0568', '172U1A0569', '172U1A0570', '172U1A0571', '172U1A0572', '172U1A0573', '172U1A0574', '172U1A0575', '172U1A0576', '172U1A0577', '172U1A0578', '172U1A0579', '172U1A0580', '172U1A0581', '172U1A0582', '172U1A0583', '172U1A0584', '172U1A0585', '172U1A0586', '172U1A0587', '172U1A0588', '172U1A0589', '172U1A0590', '172U1A0591', '172U1A0592', '172U1A0593', '172U1A0594', '172U1A0595', '172U1A0596', '172U1A0597', '172U1A0598', '172U1A0599']

# %%
import numpy as np
import pandas as pd

# %%
python=np.random.randint(0,100,100)
print(python)
c=np.random.randint(0,100,100)
java=np.random.randint(0,100,100)
da=np.random.randint(0,100,100)
# Out:
# [94 63 44 58 51 19 62  5 88  0 89 70 34 96 17 60 87  1 90 75 53 96 23 11
#   6 86 38 18 45 56 41 62 33  6 91 76 21 64 56 75 91 82  1 37 50 69 52  0
#  89 99 69 89 48  4 71 17 76 53 84 74  2 24 18 56 23 75 61 17 28 83 87  8
#  72 45 62  6 76 43 92  1  8 99 28 65 65 13 18 41 42  6 29 47 13 11 72  5
#  20 93 82 24]

# %%
student_data={'roll_numbers':roll_numbers,'Python':python,'c':c,'java':java,'da':da}
data=pd.DataFrame(student_data)
print(data)
# Out:
#    roll_numbers  Python   c  java  da
# 0    172U1A0500      94  31    24  43
# 1    172U1A0501      63  53    98  64
# 2    172U1A0502      44  59    61  97
# 3    172U1A0503      58  91    34  13
# 4    172U1A0504      51  30    94  18
# ..          ...     ...  ..   ...  ..
# 95   172U1A0595       5  22    12   0
# 96   172U1A0596      20  85    88  94
# 97   172U1A0597      93  92    34  47
# 98   172U1A0598      82  67    75   1
# 99   172U1A0599      24  61    24  11
#
# [100 rows x 5 columns]

# %%
print(len(python))
# Out:
# 100

# %%
data.head()
# Out:
#   roll_numbers  Python   c  java  da
# 0   172U1A0500      94  31    24  43
# 1   172U1A0501      63  53    98  64
# 2   172U1A0502      44  59    61  97
# 3   172U1A0503      58  91    34  13
# 4   172U1A0504      51  30    94  18

# %%
data.head(20)
# Out:
#    roll_numbers  Python   c  java  da
# 0    172U1A0500      94  31    24  43
# 1    172U1A0501      63  53    98  64
# 2    172U1A0502      44  59    61  97
# 3    172U1A0503      58  91    34  13
# 4    172U1A0504      51  30    94  18
# 5    172U1A0505      19  11    53  43
# 6    172U1A0506      62  95    37   0
# 7    172U1A0507       5  59    88   0
# 8    172U1A0508      88  76    79  52
# 9    172U1A0509       0  30    97  82
# 10   172U1A0510      89  34     1  29
# 11   172U1A0511      70  71     2  97
# 12   172U1A0512      34  27    75  93
# 13   172U1A0513      96  80     8  99
# 14   172U1A0514      17  53    74  39
# 15   172U1A0515      60  47    95   2
# 16   172U1A0516      87  71    92  29
# 17   172U1A0517       1  58    63  77
# 18   172U1A0518      90  36    70  83
# 19   172U1A0519      75  76    81  20

# %%
data.tail()
# Out:
#    roll_numbers  Python   c  java  da
# 95   172U1A0595       5  22    12   0
# 96   172U1A0596      20  85    88  94
# 97   172U1A0597      93  92    34  47
# 98   172U1A0598      82  67    75   1
# 99   172U1A0599      24  61    24  11

# %%
data.tail(50)
# Out:
#    roll_numbers  Python   c  java  da
# 50   172U1A0550      69   6    61  67
# 51   172U1A0551      89  47    95   8
# 52   172U1A0552      48  84    62  58
# 53   172U1A0553       4  49    46   9
# 54   172U1A0554      71  34    67  73
# 55   172U1A0555      17   3    93  68
# 56   172U1A0556      76  52     4  44
# 57   172U1A0557      53  96    50  97
# 58   172U1A0558      84  34     4  46
# 59   172U1A0559      74  42    49  99
# 60   172U1A0560       2  55    63  37
# 61   172U1A0561      24  57    90  42
# 62   172U1A0562      18  61    50  50
# 63   172U1A0563      56   1    54  83
# 64   172U1A0564      23  79    66  80
# 65   172U1A0565      75  89    64  53
# 66   172U1A0566      61  10     7  40
# 67   172U1A0567      17  17     7  62
# 68   172U1A0568      28  86     4  94
# 69   172U1A0569      83  54    58  26
# 70   172U1A0570      87  54    44  69
# 71   172U1A0571       8  80    11  74
# 72   172U1A0572      72   6    34  22
# 73   172U1A0573      45   6    11  42
# 74   172U1A0574      62  11    44  51
# 75   172U1A0575       6  56    74  64
# 76   172U1A0576      76  75    98  60
# 77   172U1A0577      43  89    32  36
# 78   172U1A0578      92  48    30  27
# 79   172U1A0579       1  11    58  19
# 80   172U1A0580       8  27    55  50
# 81   172U1A0581      99  32     9  75
# 82   172U1A0582      28  95    99   1
# 83   172U1A0583      65  85    54  90
# 84   172U1A0584      65  72    58  63
# 85   172U1A0585      13  53    96  27
# 86   172U1A0586      18  72    75   9
# 87   172U1A0587      41  81    46  71
# 88   172U1A0588      42  85     1   7
# 89   172U1A0589       6  85    74  71
# 90   172U1A0590      29  59     4  23
# 91   172U1A0591      47  88    55  30
# 92   172U1A0592      13  22    67  28
# 93   172U1A0593      11   9    59  94
# 94   172U1A0594      72   9     6  32
# 95   172U1A0595       5  22    12   0
# 96   172U1A0596      20  85    88  94
# 97   172U1A0597      93  92    34  47
# 98   172U1A0598      82  67    75   1
# 99   172U1A0599      24  61    24  11

# %%
data[['roll_numbers','Python']]
type(data[['roll_numbers','Python']])
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[37][['roll_numbers','c','java']]
# Out:
# roll_numbers    172U1A0537
# c                       78
# java                    93
# Name: 37, dtype: object

# %%
data2
# Out:
# array([88, 86, 74, 85, 78, 81, 80, 41, 82, 69])

# %%
data['total_marks']=data.sum(axis='columns')

# %%
data
# Out:
#    roll_numbers  Python   c  java  da  total_marks
# 0    172U1A0500      94  31    24  43          192
# 1    172U1A0501      63  53    98  64          278
# 2    172U1A0502      44  59    61  97          261
# 3    172U1A0503      58  91    34  13          196
# 4    172U1A0504      51  30    94  18          193
# ..          ...     ...  ..   ...  ..          ...
# 95   172U1A0595       5  22    12   0           39
# 96   172U1A0596      20  85    88  94          287
# 97   172U1A0597      93  92    34  47          266
# 98   172U1A0598      82  67    75   1          225
# 99   172U1A0599      24  61    24  11          120
#
# [100 rows x 6 columns]

# %%
data['percentage']=(data['total_marks']*100)/400

# %%
data.head()
# Out:
#   roll_numbers  Python   c  java  da  total_marks  percentage
# 0   172U1A0500      94  31    24  43          192       48.00
# 1   172U1A0501      63  53    98  64          278       69.50
# 2   172U1A0502      44  59    61  97          261       65.25
# 3   172U1A0503      58  91    34  13          196       49.00
# 4   172U1A0504      51  30    94  18          193       48.25

# %%
data['pass/fail']=np.zeros(100)
print(data)
# Out:
#    roll_numbers  Python   c  java  da  total_marks  percentage  pass/fail
# 0    172U1A0500      94  31    24  43          192       48.00        0.0
# 1    172U1A0501      63  53    98  64          278       69.50        0.0
# 2    172U1A0502      44  59    61  97          261       65.25        0.0
# 3    172U1A0503      58  91    34  13          196       49.00        0.0
# 4    172U1A0504      51  30    94  18          193       48.25        0.0
# ..          ...     ...  ..   ...  ..          ...         ...        ...
# 95   172U1A0595       5  22    12   0           39        9.75        0.0
# 96   172U1A0596      20  85    88  94          287       71.75        0.0
# 97   172U1A0597      93  92    34  47          266       66.50        0.0
# 98   172U1A0598      82  67    75   1          225       56.25        0.0
# 99   172U1A0599      24  61    24  11          120       30.00        0.0
#
# [100 rows x 8 columns]

# %%
### Grading --->Pass/Fail
data
data['pass/fail'][data['percentage']>=40]='pass'
data['pass/fail'][data['percentage']<40]='fail'
data
# Out:
# <ipython-input-75-0bc339a9207c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pass/fail'][data['percentage']>=40]='pass'
# <ipython-input-75-0bc339a9207c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pass/fail'][data['percentage']<40]='fail'
#    roll_numbers  Python   c  java  da  total_marks  percentage pass/fail
# 0    172U1A0500      94  31    24  43          192       48.00      pass
# 1    172U1A0501      63  53    98  64          278       69.50      pass
# 2    172U1A0502      44  59    61  97          261       65.25      pass
# 3    172U1A0503      58  91    34  13          196       49.00      pass
# 4    172U1A0504      51  30    94  18          193       48.25      pass
# ..          ...     ...  ..   ...  ..          ...         ...       ...
# 95   172U1A0595       5  22    12   0           39        9.75      fail
# 96   172U1A0596      20  85    88  94          287       71.75      pass
# 97   172U1A0597      93  92    34  47          266       66.50      pass
# 98   172U1A0598      82  67    75   1          225       56.25      pass
# 99   172U1A0599      24  61    24  11          120       30.00      fail
#
# [100 rows x 8 columns]

# %% [markdown]
# # Seaborn
#     - apply styles to the plot
#     - themes to the plot
#     - Data set plots
#       - Categorical Scatterplot
#         - stripplot(with kind = "Strip"
#         - swarmplot(with kind = "Swarm"
#       - Categorical distribution plots
#          - boxplot(with kind = "Box"
#          - violin(with kind = "violin"
#       - joint plot
#       - Regression plot
#       - heatmaps
#       - pairplots
#       - Background
#          -Darkgrid
#          -whitegrid
#          -Datk
#          -white
#          -Ticks

# %%
import numpy as np
import pandas as pd
import seaborn as ns
import matplotlib.pyplot as plt

# %%
ns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
mydata_iris=ns.load_dataset('iris')
mydata_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
mydata_iris=ns.load_dataset('iris')
mydata_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
mydata_iris.shape
# Out:
# (150, 5)

# %%
mydata_iris['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
mydata_iris.groupby('species').count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
mydata_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
mydata_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
mydata_iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
mydata_iris.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
mydata_iris.plot()
# Out:
# <AxesSubplot:>

# %%
ns.catplot(data=mydata_iris)

# %%
ns.catplot(x='species',y='sepal_width',data=mydata_iris)

# %%
ns.catplot(x='species',y='sepal_width',data=mydata_iris)
ns.catplot(x='species',y='sepal_length',data=mydata_iris)
ns.catplot(x='species',y='petal_width',data=mydata_iris)
ns.catplot(x='species',y='petal_length',data=mydata_iris)

# %%
ns.catplot(x='species',y='sepal_width',data=mydata_iris)
ns.catplot(x='species',y='sepal_length',data=mydata_iris)
ns.catplot(x='species',y='petal_width',data=mydata_iris)
ns.catplot(x='species',y='petal_length',data=mydata_iris,kind='swarm')

# %%
ns.catplot(x='species',y='sepal_width',data=mydata_iris,kind='box')
ns.catplot(x='species',y='sepal_length',data=mydata_iris)
ns.catplot(x='species',y='petal_width',data=mydata_iris)
ns.catplot(x='species',y='petal_length',data=mydata_iris,kind='swarm')

# %%
ns.violinplot(x='species',y='petal_width',data=mydata_iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
ns.violinplot(x='species',y='petal_width',data=mydata_iris)
ns.violinplot(x='species',y='petal_length',data=mydata_iris)
ns.violinplot(x='species',y='sepal_width',data=mydata_iris)
ns.violinplot(x='species',y='sepal_length',data=mydata_iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
ns.violinplot(x='species',y='petal_width',data=mydata_iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
ns.violinplot(x='species',y='petal_length',data=mydata_iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
ns.violinplot(x='species',y='sepal_width',data=mydata_iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
ns.violinplot(x='species',y='sepal_length',data=mydata_iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
ns.jointplot(x='sepal_length',y='sepal_width',data=mydata_iris,kind='reg')

# %%
ns.jointplot(x='sepal_width',y='sepal_width',data=mydata_iris,kind='reg')

# %%
ns.jointplot(x='petal_length',y='petal_width',data=mydata_iris,kind='reg')

# %%
ns.jointplot(x='petal_length',y='petal_width',data=mydata_iris,kind='hex')

# %%
ns.pairplot(data=mydata_iris,hue='species')

# %%
ns.palplot(ns.color_palette())

# %%
ns.palplot(ns.color_palette('BrBG',n_colors=15))

# %%
ns.palplot(ns.color_palette('RdBu',n_colors=15))

# %%
ns.palplot(ns.color_palette(reverse=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-044443cf91a9> in <module>
# ----> 1 ns.palplot(ns.color_palette(reverse=True))
#
# TypeError: color_palette() got an unexpected keyword argument 'reverse'
