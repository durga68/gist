# %% [markdown]
# # Title
# ## sub title
# ### Headings
# #### sub headings

# %% [markdown]
# - Outdoor Games
# 1. Cricket
# 2. Volley Ball
# 3. Throw Ball
# - Indoor Games
# 1. Carroms
# 2. Chess

# %% [markdown]
# ***
# 1. Git
# 2. Python
# 3. numpy
# 4. Pandas
# ***

# %% [markdown]
# ![image](https://wallpaperaccess.com/full/2118621.jpg)

# %% [markdown]
# <img src="download.jpg" />

# %% [markdown]
# ![image](download.jpg)

# %% [markdown]
# # To highlight particular lines using markdown
# - here writing Python Program
# - markdown is used for writing digital documentation
# ```Python
# a=int(input('enter a number'))
# if a%2==0:
#     print('a is even number')
# else:
#     print('a is odd number')
#  ```

# %% [markdown]
# # To highlight particular lines using markdown
# - here writing Python Program
# - markdown is used for writing digital documentation
# `Python
# a=int(input('enter a number'))
# if a%2==0:
#     print('a is even number')
# else:
#     print('a is odd number')
#  `

# %% [markdown]
# [GOOGLE](https://www.google.com)
#
# [FACEBOOK](https://www.facebook.com)
#
# [APSSDC](https://www.apssdc.in)

# %% [markdown]
# - this is a normal text
# - *this is an italic*
# - **this is a bold**
# - this is an *italic* and **bold**
